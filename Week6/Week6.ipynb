# %%
def duplicates_remover(lst):
    tup = set(lst)
    return [item for item in tup]
l = [1,1,5,6,6,7,8,7]
duplicates_remover(l)
# Out:
# [1, 5, 6, 7, 8]

# %%
def accumulated_sum(list):
    sum = 0
    arr = []
    count = 0
    while count <= len(list):
        for i in range(count):
            sum += list[i]
        arr.append(sum)
        sum = 0
        count += 1
    return arr
accumulated_sum(l)
# Out:
# [0, 1, 2, 7, 13, 19, 26, 34, 41]

# %%
def spin_tuple(tup, k):
    n = len(tup)
    x = k % n
    phan_dau = tup[:x]
    phan_sau = tup[x:]
    res = phan_sau + phan_dau
    
    return res
tup = (4,5,6,7)
spin_tuple(tup, 2)
# Out:
# (6, 7, 4, 5)

# %%
def create_index_map():
    text = input("Nhập chuỗi (các từ cách nhau bởi dấu cách): ")
    
    words = text.split()
    index_map = {}
    for index, word in enumerate(words):
        if word in index_map:
            index_map[word].append(index)
        else:
            index_map[word] = [index]
    for word in index_map:
        index_map[word] = tuple(index_map[word])
    print(index_map)
create_index_map()
# Out:
# {'a': (0,), 'b': (1,), 'c': (2,), 'd': (3,), 'e': (4,)}

# %%
def numb_dict(list):
    positives = []
    negatives = []
    zeros = []
    for i in list:
        if i > 0: positives.append(i)
        elif i < 0: negatives.append(i)
        else: zeros.append(i)
    dict = {}
    dict["positives"] = positives
    dict["negatives"] = negatives
    dict["zeros"] = zeros
    return dict
numb_dict(l)
# Out:
# {'positives': [1, 1, 5, 6, 6, 7, 8, 7], 'negatives': [], 'zeros': []}

# %%
def sum_of_list(list):
    return sum(list)
sum_of_list(l)
# Out:
# 41

# %%
def tuple_play(tup):
    print(tup[0])
    print(tup[-1])
    print(tup[::-1])
t = (3,5,67,8)
tuple_play(t)
# Out:
# 3
# 8
# (8, 67, 5, 3)

# %%
def count(list):
    dict = {}
    for i in list:
        if i not in dict:
            dict[i] = 1
        else:
            dict[i] = dict[i] + 1
    return dict
count(l)
# Out:
# {1: 2, 5: 1, 6: 2, 7: 2, 8: 1}

# %%
def concat_dictionary(dict1, dict2):
    res = dict1.copy()

    for key, value in dict2.items():

        if key in res:
            res[key] += value
        else:
            res[key] = value

    keys = sorted(res.keys())
    dict = {key: res[key] for key in keys}
    
    return dict

def string_to_dict(s):
    d = {}
    try:
        if not s.strip():
            return {}
        pairs = s.split(',')
        for pair in pairs:
            key, value_str = pair.split(':')
            d[key.strip()] = int(value_str.strip())
    except Exception as e:
        raise ValueError(f"{e}")
    return d

# %%
def find_sum_pairs(k, data_list):
    n = len(data_list)
    res = []
    
    for i in range(n):
        for j in range(i + 1, n):
            num1 = data_list[i]
            num2 = data_list[j]

            if num1 + num2 == k:
                if num1 != num2:
                    pair = (num1, num2)
                    pair = sorted(pair)
                    res.append(pair)
    res.sort()
    return res
lst = [1,56,74,6,3,2]
find_sum_pairs(5, lst)
# Out:
# [[2, 3]]

# %%
def tuple_filter(tup):
    odd = []
    even = []
    for i in tup:
        if i % 2 == 0: 
            even.append(i)
        else: odd.append(i)
    print(tuple(odd))
    print(tuple(even))
tup = (1,4,6,7,8)
tuple_filter(tup)
# Out:
# (1, 7)
# (4, 6, 8)

# %%
def freq(L):
     st = {}
     for i in set(L):
        st.update({L.count(i):i})
     print (st.get(max(st)))
freq(l)
# Out:
# 7

# %%
def reverse_dict(dict):
    res = {}
    for i in dict:
        res[dict[i]] = i
    return res

# %%
def find_equal_numbs(list1, list2):
    res = []
    for i in list1:
        if i in list2:
            res.append(i)
    return res

# %%
def filtered_dict(dict, k):
    res = {}
    for i in dict:
        if dict[i] > k:
            res[i] = dict[i]
    return res
